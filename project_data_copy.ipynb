# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
from datetime import datetime as dt
from sqlalchemy import create_engine, inspect
import csv
from config import db_user, db_password, db_host, db_port, db_name

# %% [markdown]
# ## Extract csv into DataFrame

# %%
csv_file = "data/US_Accidents_Dec20_Updated.csv"
accident_data_df = pd.read_csv(csv_file)
accident_data_df.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40  34.808868
# 1  A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50  35.090080
# 2  A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00  37.145730
# 3  A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46  39.110390
# 4  A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49  26.102942
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -82.269157  34.808868  -82.269157           0.0
# 1  -80.745560  35.090080  -80.745560           0.0
# 2 -121.985052  37.165850 -121.988062           1.4
# 3 -119.773781  39.110390 -119.773781           0.0
# 4  -80.265091  26.102942  -80.265091           0.0
#
#                                          Description  ...  Roundabout Station  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.  ...       False   False
# 1  Accident on Houston Branch Rd at Providence Br...  ...       False   False
# 2  Stationary traffic on CA-17 from Summit Rd (CA...  ...       False   False
# 3         Accident on US-395 Southbound at Topsy Ln.  ...       False   False
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...  ...       False   False
#
#     Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0  False           False          False        False            Day
# 1  False           False          False        False            Day
# 2  False           False          False        False          Night
# 3  False           False           True        False            Day
# 4  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2          Night             Night                 Night
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 47 columns]

# %%
csv_file2 = "data/WeatherEvents_Jan2016-Dec2020.csv"
weather_data_df = pd.read_csv(csv_file2)
weather_data_df.head()
# Out:
#   EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1     W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2     W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3     W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4     W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
#
#       TimeZone AirportCode  LocationLat  LocationLng      City    County  \
# 0  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 1  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 2  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 3  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 4  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
#
#   State  ZipCode
# 0    CO  81149.0
# 1    CO  81149.0
# 2    CO  81149.0
# 3    CO  81149.0
# 4    CO  81149.0

# %% [markdown]
# ## Transform DataFrames

# %% [markdown]
# ### Accident DataFrame

# %%
# Change to date & time columns
accident_data_df['date'] = pd.to_datetime(accident_data_df['Start_Time']).dt.date
accident_data_df['time'] = pd.to_datetime(accident_data_df['Start_Time']).dt.time

# Fix data type
pd.to_datetime(accident_data_df["date"], yearfirst=True, format='%Y-%m-%d')
# Out:
# 0         2019-05-21
# 1         2019-10-07
# 2         2020-12-13
# 3         2018-04-17
# 4         2016-08-31
#              ...
# 2906605   2018-06-28
# 2906606   2019-01-10
# 2906607   2020-11-23
# 2906608   2019-12-29
# 2906609   2018-03-26
# Name: date, Length: 2906610, dtype: datetime64[ns]

# %%
# Remove unneccessary columns
transformed_accident = accident_data_df[["ID", "date", "time", "Start_Lat", "Start_Lng", "Description", "Severity", "City", "State", "Visibility(mi)", "Wind_Speed(mph)", "Precipitation(in)", "Weather_Condition"]]
transformed_accident.head()
# transformed_accident.count()
# Out:
#     ID        date      time  Start_Lat   Start_Lng  \
# 0  A-1  2019-05-21  08:29:55  34.808868  -82.269157
# 1  A-2  2019-10-07  17:43:09  35.090080  -80.745560
# 2  A-3  2020-12-13  21:53:00  37.145730 -121.985052
# 3  A-4  2018-04-17  16:51:23  39.110390 -119.773781
# 4  A-5  2016-08-31  17:40:49  26.102942  -80.265091
#
#                                          Description  Severity  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.         2
# 1  Accident on Houston Branch Rd at Providence Br...         2
# 2  Stationary traffic on CA-17 from Summit Rd (CA...         2
# 3         Accident on US-395 Southbound at Topsy Ln.         2
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...         3
#
#               City State  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  \
# 0       Greenville    SC            10.0              7.0                0.0
# 1        Charlotte    NC            10.0              3.0                0.0
# 2        Los Gatos    CA            10.0              6.0                0.0
# 3      Carson City    NV            10.0              4.6                NaN
# 4  Fort Lauderdale    FL            10.0             13.8                NaN
#
#   Weather_Condition
# 0              Fair
# 1            Cloudy
# 2              Fair
# 3             Clear
# 4          Overcast

# %%
#Rename columns
transformed_accident = transformed_accident.rename(columns = {"Start_Time" : "start_time",
                                                            "ID": "id",
                                                            "Start_Lat" : "lat",
                                                            "Start_Lng" : "lng",
                                                            "Description": "description",
                                                            "Severity": "severity",
                                                            "City": "city",
                                                            "State": "state",
                                                            "Visibility(mi)": "visibility",
                                                            "Wind_Speed(mph)": "wind_speed",
                                                            "Precipitation(in)": "precipitation",
                                                            "Weather_Condition": "weather_condition"
                                                            })

transformed_accident.head()
# Out:
#     id        date      time        lat         lng  \
# 0  A-1  2019-05-21  08:29:55  34.808868  -82.269157
# 1  A-2  2019-10-07  17:43:09  35.090080  -80.745560
# 2  A-3  2020-12-13  21:53:00  37.145730 -121.985052
# 3  A-4  2018-04-17  16:51:23  39.110390 -119.773781
# 4  A-5  2016-08-31  17:40:49  26.102942  -80.265091
#
#                                          description  severity  \
# 0            Accident on Tanner Rd at Pennbrooke Ln.         2
# 1  Accident on Houston Branch Rd at Providence Br...         2
# 2  Stationary traffic on CA-17 from Summit Rd (CA...         2
# 3         Accident on US-395 Southbound at Topsy Ln.         2
# 4  Accident on I-595 Westbound at Exit 4 / Pine I...         3
#
#               city state  visibility  wind_speed  precipitation  \
# 0       Greenville    SC        10.0         7.0            0.0
# 1        Charlotte    NC        10.0         3.0            0.0
# 2        Los Gatos    CA        10.0         6.0            0.0
# 3      Carson City    NV        10.0         4.6            NaN
# 4  Fort Lauderdale    FL        10.0        13.8            NaN
#
#   weather_condition
# 0              Fair
# 1            Cloudy
# 2              Fair
# 3             Clear
# 4          Overcast

# %% [markdown]
# ## Extract Year & Filter by State

# %%
# Change to datetime data type
transformed_accident['date'] = pd.to_datetime(transformed_accident['date'])

# Extract year, month, and day
transformed_accident['year'] = transformed_accident['date'].dt.year
# transformed_accident['month'] = transformed_accident['start_time'].dt.month
# transformed_accident['day'] = transformed_accident['start_time'].dt.day

# Filter only CA & year: 2018
ca_2018_accident = transformed_accident.loc[(transformed_accident["state"] == "CA") & (transformed_accident["year"] == 2018)]
ca_2019_accident = transformed_accident.loc[(transformed_accident["state"] == "CA") & (transformed_accident["year"] == 2019)]

# %%
# Sort df by date
accident_ca = ca_2019_accident.sort_values(by = "date")

# %%
# Print out df
accident_ca
# Out:
#                 id       date      time        lat         lng  \
# 1762062  A-1762063 2019-01-01  05:58:45  34.229301 -118.259348
# 1838792  A-1838793 2019-01-01  08:15:05  41.730831 -123.432533
# 1773577  A-1773578 2019-01-01  04:46:00  38.661070 -121.361125
# 1238845  A-1238846 2019-01-01  08:12:27  33.996441 -117.364876
# 687134    A-687135 2019-01-01  07:05:30  34.085620 -118.216730
# ...            ...        ...       ...        ...         ...
# 720909    A-720910 2019-12-31  04:04:53  33.883411 -117.539063
# 240085    A-240086 2019-12-31  13:01:00  34.020578 -117.814393
# 1983248  A-1983249 2019-12-31  18:10:00  33.975263 -117.889186
# 1664710  A-1664711 2019-12-31  12:43:00  39.314732 -120.203913
# 2535328  A-2535329 2019-12-31  20:19:00  36.734351 -120.296310
#
#                                                description  severity  \
# 1762062                    At Pennsylvania Ave - Accident.         2
# 1838792                    Accident on CA-96 at River Trl.         2
# 1773577        Between I-80 and Hillsdale Blvd - Accident.         2
# 1238845  Lane blocked due to accident on CA-60 Eastboun...         2
# 687134   Between Westbound I-5 Acc and Avenue 43 - Acci...         2
# ...                                                    ...       ...
# 720909   Right hand shoulder blocked due to accident on...         2
# 240085                                At CA-57 - Accident.         2
# 1983248                        At S Nogales St - Accident.         2
# 1664710                                At I-80 - Accident.         2
# 2535328       At S San Benito Ave/W Panoche Rd - Accident.         2
#
#                     city state  visibility  wind_speed  precipitation  \
# 1762062     La Crescenta    CA        10.0         3.5            NaN
# 1838792       Happy Camp    CA        10.0         4.6            NaN
# 1773577       Sacramento    CA        10.0         9.2            NaN
# 1238845        Riverside    CA        10.0        13.8            NaN
# 687134       Los Angeles    CA        10.0         NaN            NaN
# ...                  ...   ...         ...         ...            ...
# 720909            Corona    CA        10.0        20.0            0.0
# 240085       Diamond Bar    CA        10.0         5.0            NaN
# 1983248  Rowland Heights    CA        10.0         5.0            0.0
# 1664710          Truckee    CA        10.0         0.0            0.0
# 2535328     Tranquillity    CA         4.0         0.0            0.0
#
#         weather_condition  year
# 1762062             Clear  2019
# 1838792             Clear  2019
# 1773577             Clear  2019
# 1238845             Clear  2019
# 687134              Clear  2019
# ...                   ...   ...
# 720909      Mostly Cloudy  2019
# 240085               Fair  2019
# 1983248              Fair  2019
# 1664710     Partly Cloudy  2019
# 2535328              Fair  2019
#
# [168526 rows x 14 columns]

# %%
# Clean the data by dropping duplicates & dropping na
accident_ca.drop_duplicates
#accident_ca.dropna(how="any", inplace=True)

# Reset index & sort
accident_ca = accident_ca.set_index(['date'])
accident_ca.sort_index(inplace=True, ascending=True)
accident_ca.reset_index(inplace=True)

# %%
# Count values
accident_ca.count()
# Out:
# date                 168526
# id                   168526
# time                 168526
# lat                  168526
# lng                  168526
# description          168526
# severity             168526
# city                 168524
# state                168526
# visibility           164404
# wind_speed           158093
# precipitation        134890
# weather_condition    164335
# year                 168526
# dtype: int64

# %%
# Print out df
accident_ca
# Out:
#              date         id      time        lat         lng  \
# 0      2019-01-01  A-1762063  05:58:45  34.229301 -118.259348
# 1      2019-01-01  A-1838793  08:15:05  41.730831 -123.432533
# 2      2019-01-01  A-1773578  04:46:00  38.661070 -121.361125
# 3      2019-01-01  A-1238846  08:12:27  33.996441 -117.364876
# 4      2019-01-01   A-687135  07:05:30  34.085620 -118.216730
# ...           ...        ...       ...        ...         ...
# 168521 2019-12-31   A-720910  04:04:53  33.883411 -117.539063
# 168522 2019-12-31   A-240086  13:01:00  34.020578 -117.814393
# 168523 2019-12-31  A-1983249  18:10:00  33.975263 -117.889186
# 168524 2019-12-31  A-1664711  12:43:00  39.314732 -120.203913
# 168525 2019-12-31  A-2535329  20:19:00  36.734351 -120.296310
#
#                                               description  severity  \
# 0                         At Pennsylvania Ave - Accident.         2
# 1                         Accident on CA-96 at River Trl.         2
# 2             Between I-80 and Hillsdale Blvd - Accident.         2
# 3       Lane blocked due to accident on CA-60 Eastboun...         2
# 4       Between Westbound I-5 Acc and Avenue 43 - Acci...         2
# ...                                                   ...       ...
# 168521  Right hand shoulder blocked due to accident on...         2
# 168522                               At CA-57 - Accident.         2
# 168523                        At S Nogales St - Accident.         2
# 168524                                At I-80 - Accident.         2
# 168525       At S San Benito Ave/W Panoche Rd - Accident.         2
#
#                    city state  visibility  wind_speed  precipitation  \
# 0          La Crescenta    CA        10.0         3.5            NaN
# 1            Happy Camp    CA        10.0         4.6            NaN
# 2            Sacramento    CA        10.0         9.2            NaN
# 3             Riverside    CA        10.0        13.8            NaN
# 4           Los Angeles    CA        10.0         NaN            NaN
# ...                 ...   ...         ...         ...            ...
# 168521           Corona    CA        10.0        20.0            0.0
# 168522      Diamond Bar    CA        10.0         5.0            NaN
# 168523  Rowland Heights    CA        10.0         5.0            0.0
# 168524          Truckee    CA        10.0         0.0            0.0
# 168525     Tranquillity    CA         4.0         0.0            0.0
#
#        weather_condition  year
# 0                  Clear  2019
# 1                  Clear  2019
# 2                  Clear  2019
# 3                  Clear  2019
# 4                  Clear  2019
# ...                  ...   ...
# 168521     Mostly Cloudy  2019
# 168522              Fair  2019
# 168523              Fair  2019
# 168524     Partly Cloudy  2019
# 168525              Fair  2019
#
# [168526 rows x 14 columns]

# %%
# Export to csv files
accident_ca.to_csv("data/ca_accidents.csv")

# %% [markdown]
# ### Weather DataFrame

# %%
# Add date & time columns
weather_data_df['date'] = pd.to_datetime(weather_data_df['StartTime(UTC)']).dt.date
weather_data_df['time'] = pd.to_datetime(weather_data_df['StartTime(UTC)']).dt.time

# Fix data type
pd.to_datetime(weather_data_df["date"], yearfirst=True, format='%Y-%m-%d')
# Out:
# 0         2016-01-06
# 1         2016-01-07
# 2         2016-01-07
# 3         2016-01-08
# 4         2016-01-08
#              ...
# 6274201   2020-12-14
# 6274202   2020-12-15
# 6274203   2020-12-15
# 6274204   2020-12-23
# 6274205   2020-12-23
# Name: date, Length: 6274206, dtype: datetime64[ns]

# %%
# Remove unneccessary columns
transformed_weather = weather_data_df[["EventId", "date", "time", "LocationLat", "LocationLng", "City", "State", "Type", "Severity"]]
transformed_weather.head()
# Out:
#   EventId        date      time  LocationLat  LocationLng      City State  \
# 0     W-1  2016-01-06  23:14:00      38.0972    -106.1689  Saguache    CO
# 1     W-2  2016-01-07  04:14:00      38.0972    -106.1689  Saguache    CO
# 2     W-3  2016-01-07  05:54:00      38.0972    -106.1689  Saguache    CO
# 3     W-4  2016-01-08  05:34:00      38.0972    -106.1689  Saguache    CO
# 4     W-5  2016-01-08  13:54:00      38.0972    -106.1689  Saguache    CO
#
#    Type Severity
# 0  Snow    Light
# 1  Snow    Light
# 2  Snow    Light
# 3  Snow    Light
# 4  Snow    Light

# %%
# Rename columns
transformed_weather = transformed_weather.rename(columns = {"StartTime(UTC)" : "start_time",
                                                            "EventId": "id",
                                                            "EndTime(UTC)" : "end_time",
                                                            "LocationLat" : "lat",
                                                            "LocationLng" : "lng",
                                                            "City": "city",
                                                            "State": "state",
                                                            "Type": "type",
                                                            "Severity": "severity"})

transformed_weather.head()
# Out:
#     id        date      time      lat       lng      city state  type severity
# 0  W-1  2016-01-06  23:14:00  38.0972 -106.1689  Saguache    CO  Snow    Light
# 1  W-2  2016-01-07  04:14:00  38.0972 -106.1689  Saguache    CO  Snow    Light
# 2  W-3  2016-01-07  05:54:00  38.0972 -106.1689  Saguache    CO  Snow    Light
# 3  W-4  2016-01-08  05:34:00  38.0972 -106.1689  Saguache    CO  Snow    Light
# 4  W-5  2016-01-08  13:54:00  38.0972 -106.1689  Saguache    CO  Snow    Light

# %% [markdown]
# ## Extract Year & Filter by State

# %%
# Change to datetime data type
transformed_weather['date'] = pd.to_datetime(transformed_weather['date'])

# Extract year, month, and day
transformed_weather['year'] = transformed_weather['date'].dt.year
# transformed_weather['month'] = transformed_weather['start_time'].dt.month
# transformed_weather['day'] = transformed_weather['start_time'].dt.day

# Filter by CA & year
ca_2018_weather = transformed_weather.loc[(transformed_weather["state"] == "CA") & (transformed_weather["year"] == 2018)]
ca_2019_weather = transformed_weather.loc[(transformed_weather["state"] == "CA") & (transformed_weather["year"] == 2019)]

# %%
# Sort by date
weather_ca = ca_2019_weather.sort_values(by = "date")

# %%
# Print results
weather_ca.head()
# Out:
#                 id       date      time      lat       lng         city state  \
# 3001000  W-3001927 2019-01-01  05:30:00  37.0816 -121.5968   San Martin    CA
# 2192750  W-2193413 2019-01-01  02:22:00  32.7339 -117.1845    San Diego    CA
# 3294524  W-3295524 2019-01-01  07:54:00  35.4344 -119.0542  Bakersfield    CA
# 4968320  W-4969869 2019-01-01  11:55:00  35.2805 -116.6300   Fort Irwin    CA
# 979813    W-980094 2019-01-01  01:52:00  32.6922 -117.2098    San Diego    CA
#
#          type  severity  year
# 3001000  Cold    Severe  2019
# 2192750  Rain  Moderate  2019
# 3294524   Fog  Moderate  2019
# 4968320   Fog  Moderate  2019
# 979813   Rain     Light  2019

# %%
# Clean the data by dropping duplicates & dropping na
weather_ca.drop_duplicates
#weather_ca.dropna(how="any", inplace=True)

# Reset index & sort
weather_ca = weather_ca.set_index(['date'])
weather_ca.sort_index(inplace=True, ascending=True)
weather_ca.reset_index(inplace=True)

# %%
# Find number of records
weather_ca.count()
# Out:
# date        60155
# id          60155
# time        60155
# lat         60155
# lng         60155
# city        59526
# state       60155
# type        60155
# severity    60155
# year        60155
# dtype: int64

# %%
# Print results
weather_ca
# Out:
#             date         id      time      lat       lng         city state  \
# 0     2019-01-01  W-3001927  05:30:00  37.0816 -121.5968   San Martin    CA
# 1     2019-01-01  W-2193413  02:22:00  32.7339 -117.1845    San Diego    CA
# 2     2019-01-01  W-3295524  07:54:00  35.4344 -119.0542  Bakersfield    CA
# 3     2019-01-01  W-4969869  11:55:00  35.2805 -116.6300   Fort Irwin    CA
# 4     2019-01-01   W-980094  01:52:00  32.6922 -117.2098    San Diego    CA
# ...          ...        ...       ...      ...       ...          ...   ...
# 60150 2019-12-31  W-3476946  00:53:00  32.8342 -115.5786     Imperial    CA
# 60151 2019-12-31  W-3527802  08:39:00  37.8900 -121.2264     Stockton    CA
# 60152 2019-12-31  W-3527803  14:13:00  37.8900 -121.2264     Stockton    CA
# 60153 2019-12-31  W-3580791  07:23:00  37.6255 -120.9549      Modesto    CA
# 60154 2019-12-31  W-5967379  19:06:00  40.8034 -124.1128       Eureka    CA
#
#        type  severity  year
# 0      Cold    Severe  2019
# 1      Rain  Moderate  2019
# 2       Fog  Moderate  2019
# 3       Fog  Moderate  2019
# 4      Rain     Light  2019
# ...     ...       ...   ...
# 60150  Cold    Severe  2019
# 60151   Fog    Severe  2019
# 60152   Fog    Severe  2019
# 60153   Fog    Severe  2019
# 60154   Fog    Severe  2019
#
# [60155 rows x 10 columns]

# %%
# Export to csv's
weather_ca.to_csv("data/ca_weather.csv")

# %% [markdown]
# ## Create Database Connection

# %%
# configure the connection string
rds_connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

# confirm the connection string
# print(rds_connection_string)
        
# connect to the database
engine = create_engine(rds_connection_string)
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "project_2_db" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-24-80828c064753> in <module>
#       7 # connect to the database
#       8 engine = create_engine(rds_connection_string)
# ----> 9 conn = engine.connect()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3143             if connection is None:
#    3144                 Connection._handle_dbapi_exception_noconnection(
# -> 3145                     e, dialect, self
#    3146                 )
#    3147             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2002         elif should_wrap:
#    2003             util.raise_(
# -> 2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#    2006         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "project_2_db" does not exist
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# Append data to table
weather_ca.to_sql(name='weather', con=conn, if_exists='append', index=False)
accident_ca.to_sql(name='accidents', con=conn, if_exists='append', index=False)

# %% [markdown]
# ## Query Database

# %%
# Use inspector to find table names
Inspector = inspect(engine)
Inspector.get_table_names()

# %%
# Check weather table
pd.read_sql_query('select * from weather', con=conn).head()

# %%
# Check accidents table
pd.read_sql_query('select * from accidents', con=conn).head()
